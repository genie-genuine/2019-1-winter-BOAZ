# %%
# importing modules
import numpy as np
import pandas as pd         # dataframe 용이

# umport python lib for visulization
import matplotlib.pyplot as plt
# 노트북 페이지에 바로 그래프 나오게 
# %matplotlib inline    
import seaborn as sns
plt.style.use('seaborn')    # matplot의 기본 scheme 대신 seaborn scheme로 세팅 
sns.set(font_scale=2.5)     # seaborn의 font_scale 로 글씨 크기 통일

# import missingno as msno    # null값 확인에 용의
import warnings    # ignore warnings
warnings.filterwarnings('ignore')

# %%
# checking current working directory
import os
os.getcwd()
# Out:
# 'C:\\Users\\USER\\Documents\\Github\\2019-1-winter-BOAZ\\PYTHON\\Untitled Folder'

# %%
# ../하위폴더명
train = pd.read_csv('input/train.csv')
test = pd.read_csv('input/test.csv')
# 원데이터 복사
df_train = train
df_test = test

# %%
sns.set()
# feature에 따른 생존여부 함수 정의
def bar_chart(feature):
    survived = train[train['Survived']==1][feature].value_counts()
    dead = train[train['Survived']==0][feature].value_counts()
    df = pd.DataFrame([survived,dead])
    df.index = ['Survived', 'Dead']
    df.plot(kind='bar', stacked=True, figsize=(10,5))

# %%
sns.heatmap(train.corr(), annot=True, cmap='RdYlGn', linewidth=0.2)
fig = plt.gcf()
fig.set_size_inches(6,4)
plt.show()

# %% [markdown]
# ### FEATURE ENGINEERING

# %% [markdown]
# #### Name

# %%
train_test_data = [train, test] # combining train and test dataset
for dataset in train_test_data:
    dataset['Title'] = dataset['Name'].str.extract(' ([A-Za-z]+)\.', expand=False)

# %%
train['Title'].value_counts()
# Out:
# Mr          517
# Miss        182
# Mrs         125
# Master       40
# Dr            7
# Rev           6
# Col           2
# Mlle          2
# Major         2
# Ms            1
# Capt          1
# Don           1
# Sir           1
# Lady          1
# Jonkheer      1
# Countess      1
# Mme           1
# Name: Title, dtype: int64

# %%
pd.crosstab(train.Title, train.Sex).T.style.background_gradient(cmap='summer_r')
# Out:
# <style  type="text/css" >
#     #T_2125567a_3009_11e9_8d39_e8b1fca71ba1row0_col0 {
#             background-color:  #ffff66;
#         }    #T_2125567a_3009_11e9_8d39_e8b1fca71ba1row0_col1 {
#             background-color:  #ffff66;
#         }    #T_2125567a_3009_11e9_8d39_e8b1fca71ba1row0_col2 {
#             background-color:  #008066;
#         }    #T_2125567a_3009_11e9_8d39_e8b1fca71ba1row0_col3 {
#             background-color:  #ffff66;
#         }    #T_2125567a_3009_11e9_8d39_e8b1fca71ba1row0_col4 {
#             background-color:  #ffff66;
#         }    #T_2125567a_3009_11e9_8d39_e8b1fca71ba1row0_col5 {
#             background-color:  #ffff66;
#         }    #T_2125567a_3009_11e9_8d39_e8b1fca71ba1row0_col6 {
#             background-color:  #008066;
#         }    #T_2125567a_3009_11e9_8d39_e8b1fca71ba1row0_col7 {
#             background-color:  #ffff66;
#         }    #T_2125567a_3009_11e9_8d39_e8b1fca71ba1row0_col8 {
#             background-color:  #ffff66;
#         }    #T_2125567a_3009_11e9_8d39_e8b1fca71ba1row0_col9 {
#             background-color:  #008066;
#         }    #T_2125567a_3009_11e9_8d39_e8b1fca71ba1row0_col10 {
#             background-color:  #008066;
#         }    #T_2125567a_3009_11e9_8d39_e8b1fca71ba1row0_col11 {
#             background-color:  #008066;
#         }    #T_2125567a_3009_11e9_8d39_e8b1fca71ba1row0_col12 {
#             background-color:  #ffff66;
#         }    #T_2125567a_3009_11e9_8d39_e8b1fca71ba1row0_col13 {
#             background-color:  #008066;
#         }    #T_2125567a_3009_11e9_8d39_e8b1fca71ba1row0_col14 {
#             background-color:  #008066;
#         }    #T_2125567a_3009_11e9_8d39_e8b1fca71ba1row0_col15 {
#             background-color:  #ffff66;
#         }    #T_2125567a_3009_11e9_8d39_e8b1fca71ba1row0_col16 {
#             background-color:  #ffff66;
#         }    #T_2125567a_3009_11e9_8d39_e8b1fca71ba1row1_col0 {
#             background-color:  #008066;
#         }    #T_2125567a_3009_11e9_8d39_e8b1fca71ba1row1_col1 {
#             background-color:  #008066;
#         }    #T_2125567a_3009_11e9_8d39_e8b1fca71ba1row1_col2 {
#             background-color:  #ffff66;
#         }    #T_2125567a_3009_11e9_8d39_e8b1fca71ba1row1_col3 {
#             background-color:  #008066;
#         }    #T_2125567a_3009_11e9_8d39_e8b1fca71ba1row1_col4 {
#             background-color:  #008066;
#         }    #T_2125567a_3009_11e9_8d39_e8b1fca71ba1row1_col5 {
#             background-color:  #008066;
#         }    #T_2125567a_3009_11e9_8d39_e8b1fca71ba1row1_col6 {
#             background-color:  #ffff66;
#         }    #T_2125567a_3009_11e9_8d39_e8b1fca71ba1row1_col7 {
#             background-color:  #008066;
#         }    #T_2125567a_3009_11e9_8d39_e8b1fca71ba1row1_col8 {
#             background-color:  #008066;
#         }    #T_2125567a_3009_11e9_8d39_e8b1fca71ba1row1_col9 {
#             background-color:  #ffff66;
#         }    #T_2125567a_3009_11e9_8d39_e8b1fca71ba1row1_col10 {
#             background-color:  #ffff66;
#         }    #T_2125567a_3009_11e9_8d39_e8b1fca71ba1row1_col11 {
#             background-color:  #ffff66;
#         }    #T_2125567a_3009_11e9_8d39_e8b1fca71ba1row1_col12 {
#             background-color:  #008066;
#         }    #T_2125567a_3009_11e9_8d39_e8b1fca71ba1row1_col13 {
#             background-color:  #ffff66;
#         }    #T_2125567a_3009_11e9_8d39_e8b1fca71ba1row1_col14 {
#             background-color:  #ffff66;
#         }    #T_2125567a_3009_11e9_8d39_e8b1fca71ba1row1_col15 {
#             background-color:  #008066;
#         }    #T_2125567a_3009_11e9_8d39_e8b1fca71ba1row1_col16 {
#             background-color:  #008066;
#         }</style>
# <table id="T_2125567a_3009_11e9_8d39_e8b1fca71ba1" >
# <thead>    <tr>
#         <th class="index_name level0" >Title</th>
#         <th class="col_heading level0 col0" >Capt</th>
#         <th class="col_heading level0 col1" >Col</th>
#         <th class="col_heading level0 col2" >Countess</th>
#         <th class="col_heading level0 col3" >Don</th>
#         <th class="col_heading level0 col4" >Dr</th>
#         <th class="col_heading level0 col5" >Jonkheer</th>
#         <th class="col_heading level0 col6" >Lady</th>
#         <th class="col_heading level0 col7" >Major</th>
#         <th class="col_heading level0 col8" >Master</th>
#         <th class="col_heading level0 col9" >Miss</th>
#         <th class="col_heading level0 col10" >Mlle</th>
#         <th class="col_heading level0 col11" >Mme</th>
#         <th class="col_heading level0 col12" >Mr</th>
#         <th class="col_heading level0 col13" >Mrs</th>
#         <th class="col_heading level0 col14" >Ms</th>
#         <th class="col_heading level0 col15" >Rev</th>
#         <th class="col_heading level0 col16" >Sir</th>
#     </tr>    <tr>
#         <th class="index_name level0" >Sex</th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_2125567a_3009_11e9_8d39_e8b1fca71ba1level0_row0" class="row_heading level0 row0" >female</th>
#         <td id="T_2125567a_3009_11e9_8d39_e8b1fca71ba1row0_col0" class="data row0 col0" >0</td>
#         <td id="T_2125567a_3009_11e9_8d39_e8b1fca71ba1row0_col1" class="data row0 col1" >0</td>
#         <td id="T_2125567a_3009_11e9_8d39_e8b1fca71ba1row0_col2" class="data row0 col2" >1</td>
#         <td id="T_2125567a_3009_11e9_8d39_e8b1fca71ba1row0_col3" class="data row0 col3" >0</td>
#         <td id="T_2125567a_3009_11e9_8d39_e8b1fca71ba1row0_col4" class="data row0 col4" >1</td>
#         <td id="T_2125567a_3009_11e9_8d39_e8b1fca71ba1row0_col5" class="data row0 col5" >0</td>
#         <td id="T_2125567a_3009_11e9_8d39_e8b1fca71ba1row0_col6" class="data row0 col6" >1</td>
#         <td id="T_2125567a_3009_11e9_8d39_e8b1fca71ba1row0_col7" class="data row0 col7" >0</td>
#         <td id="T_2125567a_3009_11e9_8d39_e8b1fca71ba1row0_col8" class="data row0 col8" >0</td>
#         <td id="T_2125567a_3009_11e9_8d39_e8b1fca71ba1row0_col9" class="data row0 col9" >182</td>
#         <td id="T_2125567a_3009_11e9_8d39_e8b1fca71ba1row0_col10" class="data row0 col10" >2</td>
#         <td id="T_2125567a_3009_11e9_8d39_e8b1fca71ba1row0_col11" class="data row0 col11" >1</td>
#         <td id="T_2125567a_3009_11e9_8d39_e8b1fca71ba1row0_col12" class="data row0 col12" >0</td>
#         <td id="T_2125567a_3009_11e9_8d39_e8b1fca71ba1row0_col13" class="data row0 col13" >125</td>
#         <td id="T_2125567a_3009_11e9_8d39_e8b1fca71ba1row0_col14" class="data row0 col14" >1</td>
#         <td id="T_2125567a_3009_11e9_8d39_e8b1fca71ba1row0_col15" class="data row0 col15" >0</td>
#         <td id="T_2125567a_3009_11e9_8d39_e8b1fca71ba1row0_col16" class="data row0 col16" >0</td>
#     </tr>    <tr>
#         <th id="T_2125567a_3009_11e9_8d39_e8b1fca71ba1level0_row1" class="row_heading level0 row1" >male</th>
#         <td id="T_2125567a_3009_11e9_8d39_e8b1fca71ba1row1_col0" class="data row1 col0" >1</td>
#         <td id="T_2125567a_3009_11e9_8d39_e8b1fca71ba1row1_col1" class="data row1 col1" >2</td>
#         <td id="T_2125567a_3009_11e9_8d39_e8b1fca71ba1row1_col2" class="data row1 col2" >0</td>
#         <td id="T_2125567a_3009_11e9_8d39_e8b1fca71ba1row1_col3" class="data row1 col3" >1</td>
#         <td id="T_2125567a_3009_11e9_8d39_e8b1fca71ba1row1_col4" class="data row1 col4" >6</td>
#         <td id="T_2125567a_3009_11e9_8d39_e8b1fca71ba1row1_col5" class="data row1 col5" >1</td>
#         <td id="T_2125567a_3009_11e9_8d39_e8b1fca71ba1row1_col6" class="data row1 col6" >0</td>
#         <td id="T_2125567a_3009_11e9_8d39_e8b1fca71ba1row1_col

# %%
title_mapping = {"Mr": 0, "Miss": 1, "Mrs": 2, 
                 "Master": 3, "Dr": 3, "Rev": 3, "Col": 3, "Major": 3, "Mlle": 3,"Countess": 3,
                 "Ms": 3, "Lady": 3, "Jonkheer": 3, "Don": 3, "Dona" : 3, "Mme": 3,"Capt": 3,"Sir": 3 }

for dataset in train_test_data:
    dataset['Title'] = dataset['Title'].map(title_mapping)

# %%
pd.crosstab(train.Title, train.Survived).T.style.background_gradient(cmap='summer_r')
# Out:
# <style  type="text/css" >
#     #T_2158cbfe_3009_11e9_8bb8_e8b1fca71ba1row0_col0 {
#             background-color:  #008066;
#         }    #T_2158cbfe_3009_11e9_8bb8_e8b1fca71ba1row0_col1 {
#             background-color:  #ffff66;
#         }    #T_2158cbfe_3009_11e9_8bb8_e8b1fca71ba1row0_col2 {
#             background-color:  #ffff66;
#         }    #T_2158cbfe_3009_11e9_8bb8_e8b1fca71ba1row0_col3 {
#             background-color:  #ffff66;
#         }    #T_2158cbfe_3009_11e9_8bb8_e8b1fca71ba1row1_col0 {
#             background-color:  #ffff66;
#         }    #T_2158cbfe_3009_11e9_8bb8_e8b1fca71ba1row1_col1 {
#             background-color:  #008066;
#         }    #T_2158cbfe_3009_11e9_8bb8_e8b1fca71ba1row1_col2 {
#             background-color:  #008066;
#         }    #T_2158cbfe_3009_11e9_8bb8_e8b1fca71ba1row1_col3 {
#             background-color:  #008066;
#         }</style>
# <table id="T_2158cbfe_3009_11e9_8bb8_e8b1fca71ba1" >
# <thead>    <tr>
#         <th class="index_name level0" >Title</th>
#         <th class="col_heading level0 col0" >0</th>
#         <th class="col_heading level0 col1" >1</th>
#         <th class="col_heading level0 col2" >2</th>
#         <th class="col_heading level0 col3" >3</th>
#     </tr>    <tr>
#         <th class="index_name level0" >Survived</th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_2158cbfe_3009_11e9_8bb8_e8b1fca71ba1level0_row0" class="row_heading level0 row0" >0</th>
#         <td id="T_2158cbfe_3009_11e9_8bb8_e8b1fca71ba1row0_col0" class="data row0 col0" >436</td>
#         <td id="T_2158cbfe_3009_11e9_8bb8_e8b1fca71ba1row0_col1" class="data row0 col1" >55</td>
#         <td id="T_2158cbfe_3009_11e9_8bb8_e8b1fca71ba1row0_col2" class="data row0 col2" >26</td>
#         <td id="T_2158cbfe_3009_11e9_8bb8_e8b1fca71ba1row0_col3" class="data row0 col3" >32</td>
#     </tr>    <tr>
#         <th id="T_2158cbfe_3009_11e9_8bb8_e8b1fca71ba1level0_row1" class="row_heading level0 row1" >1</th>
#         <td id="T_2158cbfe_3009_11e9_8bb8_e8b1fca71ba1row1_col0" class="data row1 col0" >81</td>
#         <td id="T_2158cbfe_3009_11e9_8bb8_e8b1fca71ba1row1_col1" class="data row1 col1" >127</td>
#         <td id="T_2158cbfe_3009_11e9_8bb8_e8b1fca71ba1row1_col2" class="data row1 col2" >99</td>
#         <td id="T_2158cbfe_3009_11e9_8bb8_e8b1fca71ba1row1_col3" class="data row1 col3" >35</td>
#     </tr></tbody>
# </table>

# %%
# delete unnecessary feature from dataset
# drop - axis, inplace
train.drop('Name', axis=1, inplace=True)
test.drop('Name', axis=1, inplace=True)

# %% [markdown]
# #### Sex

# %%
pd.crosstab([train.Sex, train.Survived], train.Pclass, margins=True).style.background_gradient(cmap='summer_r')
# Out:
# <style  type="text/css" >
#     #T_2197191e_3009_11e9_89cd_e8b1fca71ba1row0_col0 {
#             background-color:  #ffff66;
#         }    #T_2197191e_3009_11e9_89cd_e8b1fca71ba1row0_col1 {
#             background-color:  #ffff66;
#         }    #T_2197191e_3009_11e9_89cd_e8b1fca71ba1row0_col2 {
#             background-color:  #f1f866;
#         }    #T_2197191e_3009_11e9_89cd_e8b1fca71ba1row0_col3 {
#             background-color:  #ffff66;
#         }    #T_2197191e_3009_11e9_89cd_e8b1fca71ba1row1_col0 {
#             background-color:  #96cb66;
#         }    #T_2197191e_3009_11e9_89cd_e8b1fca71ba1row1_col1 {
#             background-color:  #a3d166;
#         }    #T_2197191e_3009_11e9_89cd_e8b1fca71ba1row1_col2 {
#             background-color:  #f1f866;
#         }    #T_2197191e_3009_11e9_89cd_e8b1fca71ba1row1_col3 {
#             background-color:  #cfe766;
#         }    #T_2197191e_3009_11e9_89cd_e8b1fca71ba1row2_col0 {
#             background-color:  #a7d366;
#         }    #T_2197191e_3009_11e9_89cd_e8b1fca71ba1row2_col1 {
#             background-color:  #85c266;
#         }    #T_2197191e_3009_11e9_89cd_e8b1fca71ba1row2_col2 {
#             background-color:  #6eb666;
#         }    #T_2197191e_3009_11e9_89cd_e8b1fca71ba1row2_col3 {
#             background-color:  #85c266;
#         }    #T_2197191e_3009_11e9_89cd_e8b1fca71ba1row3_col0 {
#             background-color:  #cde666;
#         }    #T_2197191e_3009_11e9_89cd_e8b1fca71ba1row3_col1 {
#             background-color:  #f0f866;
#         }    #T_2197191e_3009_11e9_89cd_e8b1fca71ba1row3_col2 {
#             background-color:  #ffff66;
#         }    #T_2197191e_3009_11e9_89cd_e8b1fca71ba1row3_col3 {
#             background-color:  #f7fb66;
#         }    #T_2197191e_3009_11e9_89cd_e8b1fca71ba1row4_col0 {
#             background-color:  #008066;
#         }    #T_2197191e_3009_11e9_89cd_e8b1fca71ba1row4_col1 {
#             background-color:  #008066;
#         }    #T_2197191e_3009_11e9_89cd_e8b1fca71ba1row4_col2 {
#             background-color:  #008066;
#         }    #T_2197191e_3009_11e9_89cd_e8b1fca71ba1row4_col3 {
#             background-color:  #008066;
#         }</style>
# <table id="T_2197191e_3009_11e9_89cd_e8b1fca71ba1" >
# <thead>    <tr>
#         <th class="blank" ></th>
#         <th class="index_name level0" >Pclass</th>
#         <th class="col_heading level0 col0" >1</th>
#         <th class="col_heading level0 col1" >2</th>
#         <th class="col_heading level0 col2" >3</th>
#         <th class="col_heading level0 col3" >All</th>
#     </tr>    <tr>
#         <th class="index_name level0" >Sex</th>
#         <th class="index_name level1" >Survived</th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_2197191e_3009_11e9_89cd_e8b1fca71ba1level0_row0" class="row_heading level0 row0" rowspan=2>female</th>
#         <th id="T_2197191e_3009_11e9_89cd_e8b1fca71ba1level1_row0" class="row_heading level1 row0" >0</th>
#         <td id="T_2197191e_3009_11e9_89cd_e8b1fca71ba1row0_col0" class="data row0 col0" >3</td>
#         <td id="T_2197191e_3009_11e9_89cd_e8b1fca71ba1row0_col1" class="data row0 col1" >6</td>
#         <td id="T_2197191e_3009_11e9_89cd_e8b1fca71ba1row0_col2" class="data row0 col2" >72</td>
#         <td id="T_2197191e_3009_11e9_89cd_e8b1fca71ba1row0_col3" class="data row0 col3" >81</td>
#     </tr>    <tr>
#         <th id="T_2197191e_3009_11e9_89cd_e8b1fca71ba1level1_row1" class="row_heading level1 row1" >1</th>
#         <td id="T_2197191e_3009_11e9_89cd_e8b1fca71ba1row1_col0" class="data row1 col0" >91</td>
#         <td id="T_2197191e_3009_11e9_89cd_e8b1fca71ba1row1_col1" class="data row1 col1" >70</td>
#         <td id="T_2197191e_3009_11e9_89cd_e8b1fca71ba1row1_col2" class="data row1 col2" >72</td>
#         <td id="T_2197191e_3009_11e9_89cd_e8b1fca71ba1row1_col3" class="data row1 col3" >233</td>
#     </tr>    <tr>
#         <th id="T_2197191e_3009_11e9_89cd_e8b1fca71ba1level0_row2" class="row_heading level0 row2" rowspan=2>male</th>
#         <th id="T_2197191e_3009_11e9_89cd_e8b1fca71ba1level1_row2" class="row_heading level1 row2" >0</th>
#         <td id="T_2197191e_3009_11e9_89cd_e8b1fca71ba1row2_col0" class="data row2 col0" >77</td>
#         <td id="T_2197191e_3009_11e9_89cd_e8b1fca71ba1row2_col1" class="data row2 col1" >91</td>
#         <td id="T_2197191e_3009_11e9_89cd_e8b1fca71ba1row2_col2" class="data row2 col2" >300</td>
#         <td id="T_2197191e_3009_11e9_89cd_e8b1fca71ba1row2_col3" class="data row2 col3" >468</td>
#     </tr>    <tr>
#         <th id="T_2197191e_3009_11e9_89cd_e8b1fca71ba1level1_row3" class="row_heading level1 row3" >1</th>
#         <td id="T_2197191e_3009_11e9_89cd_e8b1fca71ba1row3_col0" class="data row3 col0" >45</td>
#         <td id="T_2197191e_3009_11e9_89cd_e8b1fca71ba1row3_col1" class="data row3 col1" >17</td>
#         <td id="T_2197191e_3009_11e9_89cd_e8b1fca71ba1row3_col2" class="data row3 col2" >47</td>
#         <td id="T_2197191e_3009_11e9_89cd_e8b1fca71ba1row3_col3" class="data row3 col3" >109</td>
#     </tr>    <tr>
#         <th id="T_2197191e_3009_11e9_89cd_e8b1fca71ba1level0_row4" class="row_heading level0 row4" >All</th>
#         <th id="T_2197191e_3009_11e9_89cd_e8b1fca71ba1level1_row4" class="row_heading level1 row4" ></th>
#         <td id="T_2197191e_3009_11e9_89cd_e8b1fca71ba1row4_col0" class="data row4 col0" >216</td>
#         <td id="T_2197191e_3009_11e9_89cd_e8b1fca71ba1row4_col1" class="data row4 col1" >184</td>
#         <td id="T_2197191e_3009_11e9_89cd_e8b1fca71ba1row4_col2" class="data row4 col2" >491</td>
#         <td id="T_2197191e_3009_11e9_89cd_e8b1fca71ba1row4_col3" class="data row4 col3" >891</td>
#     </tr></tbody>
# </table>

# %% [markdown]
# - Pclass가 3인 남성, Pclass가 1인 여성

# %%
sns.factorplot('Pclass', 'Survived', hue='Sex', data=train)
plt.show()

# %% [markdown]
# - %로 봤을 때의 그래프, Pclass Sex 모두 중요한 feature

# %%
sex_mapping={'male':0, 'female':1}
for dataset in train_test_data:
    dataset['Sex'] = dataset['Sex'].map(sex_mapping)

# %% [markdown]
# #### Age

# %%
train.groupby('Title')['Age'].mean()
# Out:
# Title
# 0    32.368090
# 1    21.773973
# 2    35.898148
# 3    20.430161
# Name: Age, dtype: float64

# %%
# Title 기준  평균 나이(소수 첫째자리 반올림) 로 missing Age 채우기
for dataset in train_test_data:
    dataset.loc[(dataset.Age.isnull())&(dataset.Title==0), 'Age'] = 32
    dataset.loc[(dataset.Age.isnull())&(dataset.Title==1), 'Age'] = 22
    dataset.loc[(dataset.Age.isnull())&(dataset.Title==2), 'Age'] = 36
    dataset.loc[(dataset.Age.isnull())&(dataset.Title==3), 'Age'] = 20

# %%
train.Age.isnull().value_counts()    # non null
# Out:
# False    891
# Name: Age, dtype: int64

# %%
train.Age.describe()
# Out:
# count    891.000000
# mean      29.761134
# std       13.169698
# min        0.420000
# 25%       22.000000
# 50%       30.000000
# 75%       36.000000
# max       80.000000
# Name: Age, dtype: float64

# %%
80/5
# Out:
# 16.0

# %%
# categorical 기준 변경 
for dataset in train_test_data:
    dataset.loc[ dataset['Age'] <= 16, 'Age'] = 0,
    dataset.loc[(dataset['Age'] > 16) & (dataset['Age'] <= 32), 'Age'] = 1,
    dataset.loc[(dataset['Age'] > 32) & (dataset['Age'] <= 48), 'Age'] = 2,
    dataset.loc[(dataset['Age'] > 48) & (dataset['Age'] <= 64), 'Age'] = 3,
    dataset.loc[ dataset['Age'] > 64, 'Age'] = 4

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass  Sex  Age  SibSp  Parch            Ticket  \
# 0            1         0       3    0  1.0      1      0         A/5 21171
# 1            2         1       1    1  2.0      1      0          PC 17599
# 2            3         1       3    1  1.0      0      0  STON/O2. 3101282
# 3            4         1       1    1  2.0      1      0            113803
# 4            5         0       3    0  2.0      0      0            373450
#
#       Fare Cabin Embarked  Title
# 0   7.2500   NaN        S      0
# 1  71.2833   C85        C      2
# 2   7.9250   NaN        S      1
# 3  53.1000  C123        S      2
# 4   8.0500   NaN        S      0

# %%
pd.crosstab(train.Age, train.Survived, margins=True).style.background_gradient(cmap='summer_r')
# Out:
# <style  type="text/css" >
#     #T_234abd68_3009_11e9_a1d4_e8b1fca71ba1row0_col0 {
#             background-color:  #eff766;
#         }    #T_234abd68_3009_11e9_a1d4_e8b1fca71ba1row0_col1 {
#             background-color:  #d7eb66;
#         }    #T_234abd68_3009_11e9_a1d4_e8b1fca71ba1row0_col2 {
#             background-color:  #e6f266;
#         }    #T_234abd68_3009_11e9_a1d4_e8b1fca71ba1row1_col0 {
#             background-color:  #63b166;
#         }    #T_234abd68_3009_11e9_a1d4_e8b1fca71ba1row1_col1 {
#             background-color:  #84c266;
#         }    #T_234abd68_3009_11e9_a1d4_e8b1fca71ba1row1_col2 {
#             background-color:  #6fb766;
#         }    #T_234abd68_3009_11e9_a1d4_e8b1fca71ba1row2_col0 {
#             background-color:  #cee666;
#         }    #T_234abd68_3009_11e9_a1d4_e8b1fca71ba1row2_col1 {
#             background-color:  #bdde66;
#         }    #T_234abd68_3009_11e9_a1d4_e8b1fca71ba1row2_col2 {
#             background-color:  #c7e366;
#         }    #T_234abd68_3009_11e9_a1d4_e8b1fca71ba1row3_col0 {
#             background-color:  #f2f866;
#         }    #T_234abd68_3009_11e9_a1d4_e8b1fca71ba1row3_col1 {
#             background-color:  #eaf466;
#         }    #T_234abd68_3009_11e9_a1d4_e8b1fca71ba1row3_col2 {
#             background-color:  #eff766;
#         }    #T_234abd68_3009_11e9_a1d4_e8b1fca71ba1row4_col0 {
#             background-color:  #ffff66;
#         }    #T_234abd68_3009_11e9_a1d4_e8b1fca71ba1row4_col1 {
#             background-color:  #ffff66;
#         }    #T_234abd68_3009_11e9_a1d4_e8b1fca71ba1row4_col2 {
#             background-color:  #ffff66;
#         }    #T_234abd68_3009_11e9_a1d4_e8b1fca71ba1row5_col0 {
#             background-color:  #008066;
#         }    #T_234abd68_3009_11e9_a1d4_e8b1fca71ba1row5_col1 {
#             background-color:  #008066;
#         }    #T_234abd68_3009_11e9_a1d4_e8b1fca71ba1row5_col2 {
#             background-color:  #008066;
#         }</style>
# <table id="T_234abd68_3009_11e9_a1d4_e8b1fca71ba1" >
# <thead>    <tr>
#         <th class="index_name level0" >Survived</th>
#         <th class="col_heading level0 col0" >0</th>
#         <th class="col_heading level0 col1" >1</th>
#         <th class="col_heading level0 col2" >All</th>
#     </tr>    <tr>
#         <th class="index_name level0" >Age</th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_234abd68_3009_11e9_a1d4_e8b1fca71ba1level0_row0" class="row_heading level0 row0" >0.0</th>
#         <td id="T_234abd68_3009_11e9_a1d4_e8b1fca71ba1row0_col0" class="data row0 col0" >45</td>
#         <td id="T_234abd68_3009_11e9_a1d4_e8b1fca71ba1row0_col1" class="data row0 col1" >55</td>
#         <td id="T_234abd68_3009_11e9_a1d4_e8b1fca71ba1row0_col2" class="data row0 col2" >100</td>
#     </tr>    <tr>
#         <th id="T_234abd68_3009_11e9_a1d4_e8b1fca71ba1level0_row1" class="row_heading level0 row1" >1.0</th>
#         <td id="T_234abd68_3009_11e9_a1d4_e8b1fca71ba1row1_col0" class="data row1 col0" >340</td>
#         <td id="T_234abd68_3009_11e9_a1d4_e8b1fca71ba1row1_col1" class="data row1 col1" >166</td>
#         <td id="T_234abd68_3009_11e9_a1d4_e8b1fca71ba1row1_col2" class="data row1 col2" >506</td>
#     </tr>    <tr>
#         <th id="T_234abd68_3009_11e9_a1d4_e8b1fca71ba1level0_row2" class="row_heading level0 row2" >2.0</th>
#         <td id="T_234abd68_3009_11e9_a1d4_e8b1fca71ba1row2_col0" class="data row2 col0" >115</td>
#         <td id="T_234abd68_3009_11e9_a1d4_e8b1fca71ba1row2_col1" class="data row2 col1" >90</td>
#         <td id="T_234abd68_3009_11e9_a1d4_e8b1fca71ba1row2_col2" class="data row2 col2" >205</td>
#     </tr>    <tr>
#         <th id="T_234abd68_3009_11e9_a1d4_e8b1fca71ba1level0_row3" class="row_heading level0 row3" >3.0</th>
#         <td id="T_234abd68_3009_11e9_a1d4_e8b1fca71ba1row3_col0" class="data row3 col0" >39</td>
#         <td id="T_234abd68_3009_11e9_a1d4_e8b1fca71ba1row3_col1" class="data row3 col1" >30</td>
#         <td id="T_234abd68_3009_11e9_a1d4_e8b1fca71ba1row3_col2" class="data row3 col2" >69</td>
#     </tr>    <tr>
#         <th id="T_234abd68_3009_11e9_a1d4_e8b1fca71ba1level0_row4" class="row_heading level0 row4" >4.0</th>
#         <td id="T_234abd68_3009_11e9_a1d4_e8b1fca71ba1row4_col0" class="data row4 col0" >10</td>
#         <td id="T_234abd68_3009_11e9_a1d4_e8b1fca71ba1row4_col1" class="data row4 col1" >1</td>
#         <td id="T_234abd68_3009_11e9_a1d4_e8b1fca71ba1row4_col2" class="data row4 col2" >11</td>
#     </tr>    <tr>
#         <th id="T_234abd68_3009_11e9_a1d4_e8b1fca71ba1level0_row5" class="row_heading level0 row5" >All</th>
#         <td id="T_234abd68_3009_11e9_a1d4_e8b1fca71ba1row5_col0" class="data row5 col0" >549</td>
#         <td id="T_234abd68_3009_11e9_a1d4_e8b1fca71ba1row5_col1" class="data row5 col1" >342</td>
#         <td id="T_234abd68_3009_11e9_a1d4_e8b1fca71ba1row5_col2" class="data row5 col2" >891</td>
#     </tr></tbody>
# </table>

# %%
bar_chart('Age')

# %% [markdown]
# #### Embarked

# %%
Pclass1 = train[train['Pclass']==1]['Embarked'].value_counts()
Pclass2 = train[train['Pclass']==2]['Embarked'].value_counts()
Pclass3 = train[train['Pclass']==3]['Embarked'].value_counts()
df = pd.DataFrame([Pclass1, Pclass2, Pclass3])
df.index = ['1st class','2nd class', '3rd class']
df.plot(kind='bar',stacked=True, figsize=(10,5))

# %% [markdown]
# - Q - 1등급에 거의 없다
# - S - 모든 클래스의 50% 이상 -> embark가 missing인 경우 S로 써도 무방하다
# more than 50% of 1st class are from S embark
# more than 50% of 2nd class are from S embark
# more than 50% of 3rd class are from S embark

# %%
sns.factorplot('Embarked', 'Survived', data=train)
fig=plt.gcf()
fig.set_size_inches(5,3)
plt.show()

# %% [markdown]
# - 1st에 C와 S 집중되어있는데 C에서 탑승한사람 생존 확률 50%이상

# %%
sns.factorplot('Pclass', 'Survived', hue='Sex', col= 'Embarked', data=train)
plt.show()

# %% [markdown]
# - S + 3rd class 생존 확률 매우 낮음

# %%
train['Embarked'].fillna('S', inplace=True)

# %%
train.Embarked.isnull().value_counts()
# Out:
# False    891
# Name: Embarked, dtype: int64

# %%
# convert to numeric
embarked_mapping = {'S':0, 'C':1, 'Q':2}
for dataset in train_test_data:
    dataset['Embarked'] = dataset['Embarked'].map(embarked_mapping)

# %% [markdown]
# #### Fare

# %%
# fill missing Fare with median fare for each Pclass
# train.groupby('Pclass')
# transform()
train['Fare'].fillna(train.groupby('Pclass')['Fare'].transform('median'), inplace=True)
test["Fare"].fillna(test.groupby("Pclass")["Fare"].transform("median"), inplace=True)
train.head()
# Out:
#    PassengerId  Survived  Pclass  Sex  Age  SibSp  Parch            Ticket  \
# 0            1         0       3    0  1.0      1      0         A/5 21171
# 1            2         1       1    1  2.0      1      0          PC 17599
# 2            3         1       3    1  1.0      0      0  STON/O2. 3101282
# 3            4         1       1    1  2.0      1      0            113803
# 4            5         0       3    0  2.0      0      0            373450
#
#       Fare Cabin  Embarked  Title
# 0   7.2500   NaN         0      0
# 1  71.2833   C85         1      2
# 2   7.9250   NaN         0      1
# 3  53.1000  C123         0      2
# 4   8.0500   NaN         0      0

# %%
facet = sns.FacetGrid(train, hue="Survived",aspect=4)
facet.map(sns.kdeplot,'Fare',shade= True)
facet.set(xlim=(0, train['Fare'].max()))
facet.add_legend()
plt.xlim()
# Out:
# (0.0, 512.3292)

# %%
train.Fare.describe()
# Out:
# count    891.000000
# mean      32.204208
# std       49.693429
# min        0.000000
# 25%        7.910400
# 50%       14.454200
# 75%       31.000000
# max      512.329200
# Name: Fare, dtype: float64

# %%
for dataset in train_test_data:
    dataset['Fare'] = dataset['Fare'].fillna(train['Fare'].median())
train['CategoricalFare'] = pd.qcut(train['Fare'], 4)
print (train[['CategoricalFare', 'Survived']].groupby(['CategoricalFare'], as_index=False).mean())
# Out:
#    CategoricalFare  Survived
# 0   (-0.001, 7.91]  0.197309
# 1   (7.91, 14.454]  0.303571
# 2   (14.454, 31.0]  0.454955
# 3  (31.0, 512.329]  0.581081

# %%
# Convert to numeric
# trainset 기준
# Q1,2,3 활용해 4개의 categorical 로
for dataset in train_test_data:
    dataset.loc[ dataset['Fare'] <= 8, 'Fare'] = 0,
    dataset.loc[(dataset['Fare'] > 8) & (dataset['Fare'] <= 14), 'Fare'] = 1,
    dataset.loc[(dataset['Fare'] > 14) & (dataset['Fare'] <= 31), 'Fare'] = 2,
    dataset.loc[ dataset['Fare'] > 31, 'Fare'] = 3

# %%
for dataset in train_test_data:
    dataset['Fare'] = dataset['Fare'].astype(int)

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass  Sex  Age  SibSp  Parch            Ticket  \
# 0            1         0       3    0  1.0      1      0         A/5 21171
# 1            2         1       1    1  2.0      1      0          PC 17599
# 2            3         1       3    1  1.0      0      0  STON/O2. 3101282
# 3            4         1       1    1  2.0      1      0            113803
# 4            5         0       3    0  2.0      0      0            373450
#
#    Fare Cabin  Embarked  Title  CategoricalFare
# 0     0   NaN         0      0   (-0.001, 7.91]
# 1     3   C85         1      2  (31.0, 512.329]
# 2     0   NaN         0      1   (7.91, 14.454]
# 3     3  C123         0      2  (31.0, 512.329]
# 4     1   NaN         0      0   (7.91, 14.454]

# %% [markdown]
# #### Cabin

# %%
train.Cabin.value_counts()
# Out:
# G6                 4
# B96 B98            4
# C23 C25 C27        4
# E101               3
# F2                 3
# C22 C26            3
# F33                3
# D                  3
# B57 B59 B63 B66    2
# D36                2
# B28                2
# D20                2
# E67                2
# E121               2
# E8                 2
# C68                2
# B22                2
# E33                2
# C83                2
# C126               2
# F4                 2
# C2                 2
# B77                2
# C52                2
# D26                2
# B49                2
# F G73              2
# C92                2
# E25                2
# D17                2
#                   ..
# B82 B84            1
# C110               1
# A19                1
# B79                1
# F G63              1
# C85                1
# C128               1
# A16                1
# D46                1
# C50                1
# B42                1
# B38                1
# B73                1
# B30                1
# C47                1
# C7                 1
# D30                1
# E31                1
# B41                1
# D48                1
# D15                1
# D21                1
# C103               1
# E40                1
# E17                1
# D28                1
# D47                1
# A24                1
# C118               1
# E50                1
# Name: Cabin, Length: 147, dtype: int64

# %%
for dataset in train_test_data:
    dataset['Cabin'] = dataset['Cabin'].str[:1]

# %%
# Pclass1 = train[train['Pclass']==1]['Cabin'].value_counts()
Pclass2 = train[train['Pclass']==2]['Cabin'].value_counts()
Pclass3 = train[train['Pclass']==3]['Cabin'].value_counts()
df = pd.DataFrame([Pclass1, Pclass2, Pclass3])
df.index = ['1st class','2nd class', '3rd class']
df.plot(kind='bar',stacked=True, figsize=(10,5))

# %%
# feature scaling
# 남자 - 여자 차이 VS 10달러 - 20달러 차이
# 후자를 더 크게 반영하므로 
# 범위를 반영하여 소숫점으로  숫자지정
cabin_mapping = {"A": 0, "B": 0.4, "C": 0.8, "D": 1.2, "E": 1.6, "F": 2, "G": 2.4, "T": 2.8}
for dataset in train_test_data:
    dataset['Cabin'] = dataset['Cabin'].map(cabin_mapping)

# %%
# fill missing Fare with median fare for each Pclass
train["Cabin"].fillna(train.groupby("Pclass")["Cabin"].transform("median"), inplace=True)
test["Cabin"].fillna(test.groupby("Pclass")["Cabin"].transform("median"), inplace=True)

# %% [markdown]
# #### FamilySize

# %%
# 배에 혼자 탔는지, 가족과 함께 탔는지가 중요하므로 하나의 변수로 만들자
train["FamilySize"] = train["SibSp"] + train["Parch"] + 1
test["FamilySize"] = test["SibSp"] + test["Parch"] + 1

# %%
for dataset in train_test_data:
    dataset['IsAlone'] = 0
    dataset.loc[dataset['FamilySize']==1, 'IsAlone']= 1
print(train[['IsAlone', 'Survived']].groupby(['IsAlone'], as_index=False).mean())
# Out:
#    IsAlone  Survived
# 0        0  0.505650
# 1        1  0.303538

# %%
facet = sns.FacetGrid(train, hue="Survived",aspect=4)
facet.map(sns.kdeplot,'FamilySize',shade= True)
facet.set(xlim=(0, train['FamilySize'].max()))
facet.add_legend()
plt.xlim(0)
# Out:
# (0, 11.0)

# %%
family_mapping = {1: 0, 2: 0.4, 3: 0.8, 4: 1.2, 5: 1.6, 6: 2, 7: 2.4, 8: 2.8, 9: 3.2, 10: 3.6, 11: 4}
for dataset in train_test_data:
    dataset['FamilySize'] = dataset['FamilySize'].map(family_mapping)

# %%
features_drop = ['Ticket', 'SibSp', 'Parch', 'FamilySize']
train = train.drop(features_drop, axis=1)
test = test.drop(features_drop, axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-265-257ecf0f6328> in <module>
#       1 features_drop = ['Ticket', 'SibSp', 'Parch', 'FamilySize', 'CategoricalFare']
#       2 train = train.drop(features_drop, axis=1)
# ----> 3 test = test.drop(features_drop, axis=1)
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3695                                            index=index, columns=columns,
#    3696                                            level=level, inplace=inplace,
# -> 3697                                            errors=errors)
#    3698
#    3699     @rewrite_axis_style_signature('mapper', [('copy', True),
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3109         for axis, labels in axes.items():
#    3110             if labels is not None:
# -> 3111                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3112
#    3113         if inplace:
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in _drop_axis(self, labels, axis, level, errors)
#    3141                 new_axis = axis.drop(labels, level=level, errors=errors)
#    3142             else:
# -> 3143                 new_axis = axis.drop(labels, errors=errors)
#    3144             result = self.reindex(**{axis_name: new_axis})
#    3145
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in drop(self, labels, errors)
#    4402             if errors != 'ignore':
#    4403                 raise KeyError(
# -> 4404                     '{} not found in axis'.format(labels[mask]))
#    4405             indexer = indexer[~mask]
#    4406         return self.delete(indexer)
#
# KeyError: "['CategoricalFare'] not found in axis"

# %%
train_data = train.drop('PassengerId', axis=1)

# %%
train_data = train.drop('Survived', axis=1)
target = train['Survived']

train_data.shape, target.shape
# Out:
# ((891, 9), (891,))

# %%
# 숫자로 구성된 feature 벡터 가지고 있으면 ML 가능
train_data.head()
# Out:
#    PassengerId  Pclass  Sex  Age  Fare  Cabin  Embarked  Title  IsAlone
# 0            1       3    0  1.0     0    2.0         0      0        0
# 1            2       1    1  2.0     3    0.8         1      2        0
# 2            3       3    1  1.0     0    2.0         0      1        1
# 3            4       1    1  2.0     3    0.8         0      2        0
# 4            5       3    0  2.0     1    2.0         0      0        1

# %% [markdown]
# # Modelling

# %%
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 10 columns):
# PassengerId        891 non-null int64
# Pclass             891 non-null int64
# Sex                891 non-null int64
# Age                891 non-null float64
# Fare               891 non-null int32
# Cabin              891 non-null float64
# Embarked           891 non-null int64
# Title              891 non-null int64
# CategoricalFare    891 non-null category
# IsAlone            891 non-null int64
# dtypes: category(1), float64(2), int32(1), int64(6)
# memory usage: 60.2 KB

# %%
target.head()
# Out:
# 0    0
# 1    1
# 2    1
# 3    1
# 4    0
# Name: Survived, dtype: int64

# %%
#importing Classifier Modules
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier

import numpy as np

# %% [markdown]
# ## cross validation(k-fold)

# %%
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import cross_val_predict
k_fold = KFold(n_splits=10, shuffle=True, random_state=0)

# %%
### kNN

# %%
clf = KNeighborsClassifier(n_neighbors = 13)
scoring = 'accuracy'
score = cross_val_score(clf, train_data, target, cv=k_fold, n_jobs=1, scoring=scoring)
print(score)
# Out:
# [0.5        0.62921348 0.53932584 0.59550562 0.60674157 0.57303371
#  0.49438202 0.56179775 0.56179775 0.46067416]

# %%
# kNN Score
round(np.mean(score)*100, 2)
# Out:
# 55.22

# %%
clf = DecisionTreeClassifier()
scoring = 'accuracy'
score = cross_val_score(clf, train_data, target, cv=k_fold, n_jobs=1, scoring=scoring)
print(score)
# Out:
# [0.8        0.79775281 0.82022472 0.76404494 0.86516854 0.76404494
#  0.85393258 0.82022472 0.75280899 0.79775281]

# %%
# decision tree Score
round(np.mean(score)*100, 2)
# Out:
# 80.36

# %%
xyz=[]
accuracy=[]
std=[]
classifiers = ['Linear Svm', 'Radial Svm', 'Logistic Regression', 'kNN', 'Decision Tree',
              'Naive Bayes', 'Random Forest']
models = []

# %%
clf = RandomForestClassifier(n_estimators=13)
scoring = 'accuracy'
score = cross_val_score(clf, train_data, target, cv=k_fold, n_jobs=1, scoring=scoring)
print(score)
# Out:
# [0.81111111 0.83146067 0.83146067 0.76404494 0.86516854 0.79775281
#  0.84269663 0.82022472 0.7752809  0.83146067]

# %%
# Random Forest Score
round(np.mean(score)*100, 2)
# Out:
# 81.71

# %%
clf = GaussianNB()
scoring = 'accuracy'
score = cross_val_score(clf, train_data, target, cv=k_fold, n_jobs=1, scoring=scoring)
print(score)
# Out:
# [0.84444444 0.74157303 0.73033708 0.75280899 0.71910112 0.80898876
#  0.75280899 0.78651685 0.83146067 0.84269663]

# %%
# Naive Bayes Score
round(np.mean(score)*100, 2)
# Out:
# 78.11

# %%
clf = SVC()
scoring = 'accuracy'
score = cross_val_score(clf, train_data, target, cv=k_fold, n_jobs=1, scoring=scoring)
print(score)
# Out:
# [0.83333333 0.7752809  0.80898876 0.82022472 0.84269663 0.82022472
#  0.83146067 0.85393258 0.83146067 0.85393258]

# %%
round(np.mean(score)*100,2)
# Out:
# 82.72

# %%
train.head()
# Out:
#    Survived  Pclass  Sex  Age  Fare  Cabin  Embarked  Title  FamilySize
# 0         0       3    0  1.0   0.0    2.0         0      0         0.4
# 1         1       1    1  3.0   3.0    0.8         1      2         0.4
# 2         1       3    1  1.0   0.0    2.0         0      1         0.0
# 3         1       1    1  2.0   3.0    0.8         0      2         0.4
# 4         0       3    0  2.0   1.0    2.0         0      0         0.0

# %%
clf = SVC()
clf.fit(train_data, target)

test_data = test.drop("PassengerId", axis=1).copy()
prediction = clf.predict(test_data)

# %%
test_data.isnull().sum()
# Out:
# Pclass        0
# Sex           0
# Age           0
# Fare          0
# Cabin         0
# Embarked      0
# Title         0
# FamilySize    0
# dtype: int64

# %%
submission = pd.DataFrame({
        "PassengerId": test["PassengerId"],
        "Survived": prediction
    })

# %%
submission.head()
# Out:
#    PassengerId  Survived
# 0          892         0
# 1          893         0
# 2          894         0
# 3          895         0
# 4          896         1
